# %%
import tensorflow as tf
data = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = data.load_data()
training_images = training_images / 255.0
test_images = test_images / 255.0
model = tf.keras.models.Sequential([
 tf.keras.layers.Flatten(input_shape=(28, 28)),
 tf.keras.layers.Dense(128, activation=tf.nn.relu),
 tf.keras.layers.Dense(10, activation=tf.nn.softmax)
 ])
model.compile(optimizer='adam',
 loss='sparse_categorical_crossentropy',
 metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4943 - accuracy: 0.8249
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3758 - accuracy: 0.8653
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3386 - accuracy: 0.8781
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3125 - accuracy: 0.8862
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2943 - accuracy: 0.8914

# %%
classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])
# Out:
# [7.6548877e-06 2.3187735e-07 8.9060177e-07 8.2661592e-07 1.8582634e-06
#  6.4805195e-02 4.6639085e-05 9.2332959e-02 1.8466295e-05 8.4278530e-01]
# 9

# %%
import tensorflow as tf
data = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = data.load_data()
training_images = training_images / 255.0
test_images = test_images / 255.0
model = tf.keras.models.Sequential([
 tf.keras.layers.Flatten(input_shape=(28, 28)),
 tf.keras.layers.Dense(128, activation=tf.nn.relu),
 tf.keras.layers.Dense(10, activation=tf.nn.softmax)
 ])
model.compile(optimizer='adam',
 loss='sparse_categorical_crossentropy',
 metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4998 - accuracy: 0.8244
# Epoch 2/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3788 - accuracy: 0.8625
# Epoch 3/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3379 - accuracy: 0.8763
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3123 - accuracy: 0.8850
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2948 - accuracy: 0.8919
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2799 - accuracy: 0.8959
# Epoch 7/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2667 - accuracy: 0.9007
# Epoch 8/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2576 - accuracy: 0.9048
# Epoch 9/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2473 - accuracy: 0.9077
# Epoch 10/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2377 - accuracy: 0.9108
# Epoch 11/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2309 - accuracy: 0.9136
# Epoch 12/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2228 - accuracy: 0.9159
# Epoch 13/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2153 - accuracy: 0.9185
# Epoch 14/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2095 - accuracy: 0.9226
# Epoch 15/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2055 - accuracy: 0.9228
# Epoch 16/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1976 - accuracy: 0.9261
# Epoch 17/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1914 - accuracy: 0.9280
# Epoch 18/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1885 - accuracy: 0.9284
# Epoch 19/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1818 - accuracy: 0.9318
# Epoch 20/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1770 - accuracy: 0.9338
# Epoch 21/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1740 - accuracy: 0.9345
# Epoch 22/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1703 - accuracy: 0.9356
# Epoch 23/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1650 - accuracy: 0.9373
# Epoch 24/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1628 - accuracy: 0.9382
# Epoch 25/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1581 - accuracy: 0.9407
# Epoch 26/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1541 - accuracy: 0.9428
# Epoch 27/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1507 - accuracy: 0.9427
# Epoch 28/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1474 - accuracy: 0.9451
# Epoch 29/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1416 - accuracy: 0.9470
# Epoch 30/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1417 - accuracy: 0.9470
# Epoch 31/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1374 - accuracy: 0.9488
# Epoch 32/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1337 - accuracy: 0.9498
# Epoch 33/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1322 - accuracy: 0.9505
# Epoch 34/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1307 - accuracy: 0.9505
# Epoch 35/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1262 - accuracy: 0.9529
# Epoch 36/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1242 - accuracy: 0.9540
# Epoch 37/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1232 - accuracy: 0.9533
# Epoch 38/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1180 - accuracy: 0.9551
# Epoch 39/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1196 - accuracy: 0.9546
# Epoch 40/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1156 - accuracy: 0.9569
# Epoch 41/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1143 - accuracy: 0.9567
# Epoch 42/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1119 - accuracy: 0.9578
# Epoch 43/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1089 - accuracy: 0.9593
# Epoch 44/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1079 - accuracy: 0.9587
# Epoch 45/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1062 - accuracy: 0.9603
# Epoch 46/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1025 - accuracy: 0.9615
# Epoch 47/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1018 - accuracy: 0.9623
# Epoch 48/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0994 - accuracy: 0.9618
# Epoch 49/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0983 - accuracy: 0.9625
# Epoch 50/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0966 - accuracy: 0.9632

# %%
import tensorflow as tf

class myCallback(tf.keras.callbacks.Callback):
 def on_epoch_end(self, epoch, logs={}):
  if(logs.get('accuracy')>0.95):
   print("\nReached 95% accuracy so cancelling training!")
   self.model.stop_training = True

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist

(training_images, training_labels),(test_images, test_labels) = mnist.load_data()

training_images=training_images/255.0
test_images=test_images/255.0
model = tf.keras.models.Sequential([
 tf.keras.layers.Flatten(),
 tf.keras.layers.Dense(128, activation=tf.nn.relu),
 tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
 loss='sparse_categorical_crossentropy',
 metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=50,
 callbacks=[callbacks])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5006 - accuracy: 0.8249
# Epoch 2/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3723 - accuracy: 0.8670
# Epoch 3/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3354 - accuracy: 0.8778
# Epoch 4/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3129 - accuracy: 0.8862
# Epoch 5/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2969 - accuracy: 0.8909
# Epoch 6/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2805 - accuracy: 0.8964
# Epoch 7/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2687 - accuracy: 0.9001
# Epoch 8/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2568 - accuracy: 0.9043
# Epoch 9/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2477 - accuracy: 0.9076
# Epoch 10/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2408 - accuracy: 0.9101
# Epoch 11/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2323 - accuracy: 0.9129
# Epoch 12/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2250 - accuracy: 0.9158
# Epoch 13/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2178 - accuracy: 0.9192
# Epoch 14/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2123 - accuracy: 0.9196
# Epoch 15/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2061 - accuracy: 0.9238
# Epoch 16/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1992 - accuracy: 0.9253
# Epoch 17/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1939 - accuracy: 0.9273
# Epoch 18/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1888 - accuracy: 0.9287
# Epoch 19/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1833 - accuracy: 0.9315
# Epoch 20/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1792 - accuracy: 0.9330
# Epoch 21/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1742 - accuracy: 0.9340
# Epoch 22/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1719 - accuracy: 0.9357
# Epoch 23/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1665 - accuracy: 0.9369
# Epoch 24/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1629 - accuracy: 0.9384
# Epoch 25/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1614 - accuracy: 0.9384
# Epoch 26/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1560 - accuracy: 0.9413
# Epoch 27/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1545 - accuracy: 0.9430
# Epoch 28/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1485 - accuracy: 0.9455
# Epoch 29/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1451 - accuracy: 0.9467
# Epoch 30/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1438 - accuracy: 0.9465
# Epoch 31/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1409 - accuracy: 0.9473
# Epoch 32/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1383 - accuracy: 0.9480
# Epoch 33/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1337 - accuracy: 0.9495
# Epoch 34/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1332 - accuracy: 0.9497
# Epoch 35/50
# 1861/1875 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9513
# Reached 95% accuracy so cancelling training!
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1288 - accuracy: 0.9512
